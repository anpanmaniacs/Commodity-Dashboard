# %%
# Import Dependencies
import os
import pandas as pd
from bs4 import BeautifulSoup as bs
from splinter import Browser
from selenium import webdriver
import requests
import time

def init_browser():
    """ Connects path to chromedriver """
    
    executable_path = {'executable_path': '/Users/venessayeh/Downloads/chromedriver'}
    return Browser("chrome", **executable_path, headless=False)

def scrape():
    """ Scrapes all websites for Mars data """
    
    # Create a python dictionary to store all data
    scrape_mars_dict = {}
    
    # Use requests and BeautifulSoup to scrape Nasa News for latest news
    url = 'https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'
    response = requests.get(url)
    soup = bs(response.text, 'lxml')

    results = soup.find('div', class_='features')
    news_title = results.find('div', class_='content_title').text
    newsp = results.find('div', class_='rollover_description').text
    
    # Store scraped data into dictionary
    scrape_mars_dict['news_title'] = news_title
    scrape_mars_dict['newsp'] = newsp
    
    # Scrape Mars Weather twitter for latest weather report
    twitter_url = 'https://twitter.com/marswxreport?lang=en'
    twitter_response = requests.get(twitter_url)
    twitter_soup = bs(twitter_response.text, 'lxml')
    
    twitter_result = twitter_soup.find('div', class_='js-tweet-text-container')
    mars_weather = twitter_result.find('p', class_='js-tweet-text').text
    
    # Store scraped data into dictionary
    scrape_mars_dict['mars_weather'] = mars_weather


    # Call on chromedriver function to use for splinter
    browser = init_browser()
    
    # Scrape Nasa for url of latest featured image of Mars
    nasa_url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
    browser.visit(nasa_url)

    nasa_html = browser.html
    nasa_soup = bs(nasa_html, "lxml")

    featured_image = nasa_soup.find('div', class_='default floating_text_area ms-layer').find('footer')
    featured_image_url = 'https://www.jpl.nasa.gov'+ featured_image.find('a')['data-fancybox-href']
    
    # Store url to dictionary
    scrape_mars_dict['featured_image_url'] = featured_image_url

    # Scrape astrogeology.usgs.gov for urls of hemisphere images of Mars
    hemisphere_url = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'
    browser.visit(hemisphere_url)

    hemisphere_html = browser.html
    hemisphere_soup = bs(hemisphere_html, 'lxml')
    base_url ="https://astrogeology.usgs.gov"

    image_list = hemisphere_soup.find_all('div', class_='item')

    # Create a list to store dictionary of urls and image titles
    hemisphere_image_urls = []

    # Loop through list of hemispheres and click on each one to find large resolution image
    for image in image_list:

        # Create a dicitonary to store urls and titles
        hemisphere_dict = {}
        
        # Find link to large image
        href = image.find('a', class_='itemLink product-item')
        link = base_url + href['href']

        # Visit the link
        browser.visit(link)

        # Wait 1 second 
        time.sleep(1)
        
        # Parse the html of the new page
        hemisphere_html2 = browser.html
        hemisphere_soup2 = bs(hemisphere_html2, 'lxml')

        # Find the title
        img_title = hemisphere_soup2.find('div', class_='content').find('h2', class_='title').text
        
        # Append to dict
        hemisphere_dict['title'] = img_title
    
        # Find image url
        img_url = hemisphere_soup2.find('div', class_='downloads').find('a')['href']
        
        # Append to dict
        hemisphere_dict['url_img'] = img_url
        
        # Append dict to list
        hemisphere_image_urls.append(hemisphere_dict)
    
    # Store hemisphere image urls to dictionary
    scrape_mars_dict['hemisphere_image_urls'] = hemisphere_image_urls

    return scrape_mars_dict

# %%
# Import Dependencies
import os
import pandas as pd
from bs4 import BeautifulSoup as bs
from splinter import Browser
from selenium import webdriver
import requests
import time

# %%
def init_browser():
    """ Connects path to chromedriver """
    
    executable_path = {'executable_path': '/Users/venessayeh/Downloads/chromedriver'}
    return Browser("chrome", **executable_path, headless=False)

# %%
news_url = 'https://www.foodbusinessnews.net/search?Submit=Submit&author=&datatype=&edition=&end_date=&exclude_datatypes%5B%5D=blog&ip=169.234.124.198&page=1&q=soybeans+prices&start_date=12%2F1%2F2010&utf8=%E2%9C%93'

def scrape(url):
    # Call on chromedriver function to use for splinter
    browser = init_browser()

    browser.visit(url)

    news_html = browser.html
    news_soup = bs(news_html, "lxml")
    
    headline_list = soup.find_all('div', class_='record')
    
    for headline in headline_list:
        news_dict = {} 

        description = headline.find('div', class_='abstract').text
        find_title = headline.find('a', class_='more')

        news_site = 'https://www.foodbusinessnews.net'

        if any(x in description.lower() for x in ['soybean', 'soybeans']):

            title = find_title['title']
            news_dict['title'] = title

            date = headline.find('div', class_='date').text
            news_dict['date'] = date


            href = headline.find('a', class_='more')
            link = news_site + href['href']
            news_dict['url'] = link

            print(news_dict)
        else:
            print(None)
    click_next()
    
    return news_dict
    
def click_next():
    browser = init_browser()

    browser.visit(url)

    html = browser.html
    soup = bs(html, "lxml")
    
    find_next_page = news_soup.find('a', class_='next_page')
    next_page = news_site + find_next_page['href']
    browser.visit(next_page)
    return scrape(next_page)

# %%
headline_list = news_soup.find_all('div', class_='record')
headline_list
# Out:
# [<div class="record">
#  <h2 class="headline ">
#  <a href="/articles/7-corn-futures-edge-higher-on-strong-export-sales" title="Wheat futures up on low rainfall, low protein">Wheat futures up on low rainfall, low protein</a>
#  </h2>
#  <div class="date">05.24.2018</div>
#  <div class="abstract">
#  <br/>
#  <a class="more" href="/articles/7-corn-futures-edge-higher-on-strong-export-sales" rel="" title="Wheat futures up on low rainfall, low protein">Read More</a>
#  </div>
#  </div>, <div class="record">
#  <h2 class="headline ">
#  <a href="/articles/11868-interest-in-organic-grain-trading-gathers-momentum" title="Interest in organic grain trading gathers momentum">Interest in organic grain trading gathers momentum</a>
#  </h2>
#  <div class="date">05.23.2018</div>
#  <div class="abstract">
#    Crop conditions are becoming more of an issue for organic winter wheat.<br/>
#  <a class="more" href="/articles/11868-interest-in-organic-grain-trading-gathers-momentum" rel="" title="Interest in organic grain trading gathers momentum">Read More</a>
#  </div>
#  </div>, <div class="record">
#  <h2 class="headline ">
#  <a href="/articles/11829-us-soybeans-at-risk-in-trade-dispute-with-china" title="U.S. soybeans at risk in trade dispute with China">U.S. soybeans at risk in trade dispute with China</a>
#  </h2>
#  <div class="date">05.15.2018</div>
#  <div class="abstract">
#    The importance of China to the U.S. soybean market cannot be overstated.<br/>
#  <a class="more" href="/articles/11829-us-soybeans-at-risk-in-trade-dispute-with-china" rel="" title="U.S. soybeans at risk in trade dispute with China">Read More</a>
#  </div>
#  </div>, <div class="record">
#  <h2 class="headline ">
#  <a href="/articles/11792-bay-state-milling-sowing-seeds-of-growth" title="Bay State Milling sowing seeds of growth">Bay State Milling sowing seeds of growth</a>
#  </h2>
#  <div class="date">05.10.2018</div>
#  <div class="abstract">
#    Company positioning itself for success in the 21st century.<br/>
#  <a class="more" href="/articles/11792-bay-state-milling-sowing-seeds-of-growth" rel="" title="Bay State Milling sowing seeds of growth">Read More</a>
#  </div>
#  </div>, <div class="record">
#  <h2 class="headline ">
#  <a href="/articles/11755-bunge-upbeat-despite-first-quarter-loss" title="Bunge upbeat despite first-quarter loss">Bunge upbeat despite first-quarter loss</a>
#  </h2>
#  <div class="date">05.03.2018</div>
#  <div class="abstract">
#    Raises outlook for Agribusiness, Food &amp; Ingredients divisions.<br/>
#  <a class="more" href="/articles/11755-bunge-upbeat-despite-first-quarter-loss" rel="" title="Bunge upbeat despite first-quarter loss">Read More</a>
#  </div>
#  </div>, <div class="record">
#  <h2 class="headline ">
#  <a href="/articles/11687-organic-grain-prices-mixed-in-first-quarter" title="Organic grain prices mixed in first quarter">Organic grain prices mixed in first quarter</a>
#  </h2>
#  <div class="date">04.23.2018</div>
#  <div class="abstract">
#    Corn, soybean prices lower in period.<br/>
#  <a class="more" href="/articles/11687-organic-grain-prices-mixed-in-first-quarter" rel="" title="Organic grain prices mixed in first quarter">Read More</a>
#  </div>
#  </div>, <div class="record">
#  <h2 class="headline ">
#  <a href="/articles/11622-us-soybean-carryover-down-from-march-wheat-and-corn-up" title="U.S. soybean carryover down from March, wheat and corn up">U.S. soybean carryover down from March, wheat and corn up</a>
#  </h2>
#  <div class="date">04.10.2018</div>
#  <div class="abstract">
#    Exports for all three unchanged from March.<br/>
#  <a class="more" href="/articles/11622-us-soybean-carryover-down-from-march-wheat-and-corn-up" rel="" title="U.S. soybean carryover down from March, wheat and corn up">Read More</a>
#  </div>
#  </div>, <div class="record">
#  <h2 class="headline ">
#  <a href="/articles/11586-trade-tensions-mount-between-us-and-china" title="Trade tensions mount between U.S. and China">Trade tensions mount between U.S. and China</a>
#  </h2>
#  <div class="date">04.05.2018</div>
#  <div class="abstract">
#    U.S.T.R. to accept public comments on tariff target list through May 22.<br/>
#  <a class="more" href="/articles/11586-trade-tensions-mount-between-us-and-china" rel="" title="Trade tensions mount between U.S. and China">Read More</a>
#  </div>
#  </div>, <div class="record">
#  <h2 class="headline ">
#  <a href="/articles/11533-organic-grain-prices-mixed-in-period" title="Organic grain prices mixed in period">Organic grain prices mixed in period</a>
#  </h2>
#  <div class="date">03.27.2018</div>
#  <div class="abstract">
#    Corn prices unchanged in January-February period.<br/>
#  <a class="more" href="/articles/11533-organic-grain-prices-mixed-in-period" rel="" title="Organic grain prices mixed in period">Read More</a>
#  </div>
#  </div>, <div class="record">
#  <h2 class="headline ">
#  <a href="/articles/11381-usda-chief-economist-offers-peek-into-18-ag-outlook" title="U.S.D.A. chief economist offers peek into ’18 ag outlook">U.S.D.A. chief economist offers peek into ’18 ag outlook</a>
#  </h2>
#  <div class="date">02.28.2018</div>
#  <div class="abstract">
#    Johansson focused on questions that U.S. producers have concerning the 2018 crop year such as the farm bill and trade.<br/>
#  <a class="more" href="/articles/11381-usda-chief-economist-offers-peek-into-18-ag-outlook" rel="" title="U.S.D.A. chief economist offers peek into ’18 ag outlook">Read More</a>
#  </div>
#  </div>]

# %%
for x in range(3):
    for headline in headline_list:
        news_dict = {} 

        description = headline.find('div', class_='abstract').text
        find_title = headline.find('a', class_='more')

        news_site = 'https://www.foodbusinessnews.net'

        if any(x in description.lower() for x in ['soybean', 'soybeans']):

            title = find_title['title']
            news_dict['title'] = title

            date = headline.find('div', class_='date').text
            news_dict['date'] = date


            href = headline.find('a', class_='more')
            link = news_site + href['href']
            news_dict['url'] = link

            print(news_dict)
        else:
            print(None)

    find_next_page = news_soup.find('a', class_='next_page')
    next_page = news_site + find_next_page['href']
    browser.visit(next_page)
    
    print(next_page)
# Out:
# None
# None
# {'title': 'U.S. soybeans at risk in trade dispute with China', 'date': '05.15.2018', 'url': 'https://www.foodbusinessnews.net/articles/11829-us-soybeans-at-risk-in-trade-dispute-with-china'}
# None
# None
# {'title': 'Organic grain prices mixed in first quarter', 'date': '04.23.2018', 'url': 'https://www.foodbusinessnews.net/articles/11687-organic-grain-prices-mixed-in-first-quarter'}
# None
# None
# None
# None
# https://www.foodbusinessnews.net/search?Submit=Submit&author=&datatype=&edition=&end_date=&exclude_datatypes%5B%5D=blog&ip=169.234.124.198&page=2&q=soybeans+prices&start_date=12%2F1%2F2010&utf8=%E2%9C%93
# None
# None
# {'title': 'U.S. soybeans at risk in trade dispute with China', 'date': '05.15.2018', 'url': 'https://www.foodbusinessnews.net/articles/11829-us-soybeans-at-risk-in-trade-dispute-with-china'}
# None
# None
# {'title': 'Organic grain prices mixed in first quarter', 'date': '04.23.2018', 'url': 'https://www.foodbusinessnews.net/articles/11687-organic-grain-prices-mixed-in-first-quarter'}
# None
# None
# None
# None
# https://www.foodbusinessnews.net/search?Submit=Submit&author=&datatype=&edition=&end_date=&exclude_datatypes%5B%5D=blog&ip=169.234.124.198&page=2&q=soybeans+prices&start_date=12%2F1%2F2010&utf8=%E2%9C%93
# None
# None
# {'title': 'U.S. soybeans at risk in trade dispute with China', 'date': '05.15.2018', 'url': 'https://www.foodbusinessnews.net/articles/11829-us-soybeans-at-risk-in-trade-dispute-with-china'}
# None
# None
# {'title': 'Organic grain prices mixed in first quarter', 'date': '04.23.2018', 'url': 'https://www.foodbusinessnews.net/articles/11687-organic-grain-prices-mixed-in-first-quarter'}
# None
# None
# None
# None
# https://www.foodbusinessnews.net/search?Submit=Submit&author=&datatype=&edition=&end_date=&exclude_datatypes%5B%5D=blog&ip=169.234.124.198&page=2&q=soybeans+prices&start_date=12%2F1%2F2010&utf8=%E2%9C%93
